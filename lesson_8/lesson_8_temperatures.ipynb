# %%
import pandas as pd

df = pd.read_csv("temperatures.csv")

df.head(5)
# Out:
#         day  temperature
# 0  20170101          0.5
# 1  20170102          3.0
# 2  20170103          5.0
# 3  20170104          5.8
# 4  20170105          0.0

# %%
df.describe()
# Out:
#                 day  temperature
# count  3.650000e+02   365.000000
# mean   2.017067e+07    10.965753
# std    3.454755e+02     6.034407
# min    2.017010e+07    -3.800000
# 25%    2.017040e+07     6.600000
# 50%    2.017070e+07    10.900000
# 75%    2.017100e+07    16.100000
# max    2.017123e+07    23.600000

# %%
df_warm = df[df["temperature"] > 22]

# %%
df_warm
# Out:
#           day  temperature
# 136  20170517         22.3
# 146  20170527         22.9
# 169  20170619         23.6
# 172  20170622         22.9
# 199  20170719         23.5

# %%
df_cold = df[df["temperature"] < -3]

# %%
df_cold
# Out:
#          day  temperature
# 16  20170117         -3.4
# 17  20170118         -3.8

# %%
df["freezing"] = df["temperature"] < -3

# %%
df.head(10)
# Out:
#         day  temperature  freezing
# 0  20170101          0.5     False
# 1  20170102          3.0     False
# 2  20170103          5.0     False
# 3  20170104          5.8     False
# 4  20170105          0.0     False
# 5  20170106         -3.0     False
# 6  20170107         -0.2     False
# 7  20170108          4.3     False
# 8  20170109          4.8     False
# 9  20170110          5.3     False

# %%
temperature = df["temperature"]

# %%
temperature
# Out:
# 0       0.5
# 1       3.0
# 2       5.0
# 3       5.8
# 4       0.0
# 5      -3.0
# 6      -0.2
# 7       4.3
# 8       4.8
# 9       5.3
# 10      7.2
# 11      5.2
# 12      3.1
# 13      1.8
# 14      0.7
# 15     -1.6
# 16     -3.4
# 17     -3.8
# 18     -2.0
# 19     -0.3
# 20     -0.2
# 21     -1.7
# 22      1.6
# 23      0.8
# 24     -1.1
# 25     -2.8
# 26      0.8
# 27      5.4
# 28      4.7
# 29      4.9
#        ...
# 335    -0.4
# 336     3.7
# 337     7.0
# 338     7.6
# 339     8.0
# 340     5.9
# 341     2.6
# 342     2.1
# 343     1.1
# 344    -0.1
# 345     1.8
# 346     4.0
# 347     3.3
# 348     2.6
# 349     2.7
# 350     2.5
# 351     5.9
# 352     5.2
# 353     7.5
# 354     8.4
# 355     8.6
# 356     8.7
# 357     8.2
# 358     7.4
# 359     5.8
# 360     5.1
# 361     3.9
# 362     2.8
# 363     8.8
# 364    10.6
# Name: temperature, Length: 365, dtype: float64

# %%
temperature.plot()

# %%
df_warm.to_csv("warm.csv")

# %%
temperature.plot(kind = "hist", y = "temperature", bins = 10)

# %%
temperature.plot(y = "temperature", kind = "bar")

# %%
df2 = df[0:5]

# %%
df2
# Out:
#         day  temperature  freezing
# 0  20170101          0.5     False
# 1  20170102          3.0     False
# 2  20170103          5.0     False
# 3  20170104          5.8     False
# 4  20170105          0.0     False

# %%
df
# Out:
#           day  temperature  freezing
# 0    20170101          0.5     False
# 1    20170102          3.0     False
# 2    20170103          5.0     False
# 3    20170104          5.8     False
# 4    20170105          0.0     False
# 5    20170106         -3.0     False
# 6    20170107         -0.2     False
# 7    20170108          4.3     False
# 8    20170109          4.8     False
# 9    20170110          5.3     False
# 10   20170111          7.2     False
# 11   20170112          5.2     False
# 12   20170113          3.1     False
# 13   20170114          1.8     False
# 14   20170115          0.7     False
# 15   20170116         -1.6     False
# 16   20170117         -3.4      True
# 17   20170118         -3.8      True
# 18   20170119         -2.0     False
# 19   20170120         -0.3     False
# 20   20170121         -0.2     False
# 21   20170122         -1.7     False
# 22   20170123          1.6     False
# 23   20170124          0.8     False
# ...

# %%
df2.plot(y = "temperature", kind = "bar")

# %%
df[0:10].plot (y = "temperature", kind = "bar")

# %%
df[0:10].plot (y = "temperature", kind = "bar", title = "Degrees in The Netherlands")
